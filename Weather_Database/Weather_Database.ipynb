# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 726

# %%
# Import the requests library.
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the time library.
import time

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval      ")
print("------------------------------")

# Create counters.
record_count = 1
set_count = 1


    
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate that Data Loading is complete.
print("------------------------------")
print("Data Retrieval Complete       ")
print("------------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | snasa
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | goure
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | buala
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | constitucion
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | olafsvik
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | rio gallegos
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | mulege
# Processing Record 21 of Set 1 | nueva guinea
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | kita
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | sorland
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | narasannapeta
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | laramie
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | caravelas
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | podgornoye
# Processing Record 37 of Set 1 | bolshaya vishera
# City not found. Skipping...
# Processing Record 38 of Set 1 | kuruman
# Processing Record 39 of Set 1 | bredasdorp
# Processing Record 40 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 1 | saint anthony
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | beyneu
# Processing Record 45 of Set 1 | byron bay
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | ixtapa
# Processing Record 48 of Set 1 | albany
# Processing Record 49 of Set 1 | susanville
# Processing Record 50 of Set 1 | mehamn
# Processing Record 1 of Set 2 | lavrentiya
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 2 | komsomolskiy
# Processing Record 5 of Set 2 | karamken
# City not found. Skipping...
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 2 | talnakh
# Processing Record 9 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 10 of Set 2 | esperance
# Processing Record 11 of Set 2 | kavieng
# Processing Record 12 of Set 2 | butaritari
# Processing Record 13 of Set 2 | okhotsk
# Processing Record 14 of Set 2 | san cristobal
# Processing Record 15 of Set 2 | warrington
# Processing Record 16 of Set 2 | mar del plata
# Processing Record 17 of Set 2 | banda aceh
# Processing Record 18 of Set 2 | garowe
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | padang
# Processing Record 21 of Set 2 | minas
# Processing Record 22 of Set 2 | osa
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | lorengau
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | avarua
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | hambantota
# Processing Record 30 of Set 2 | husavik
# Processing Record 31 of Set 2 | palu
# Processing Record 32 of Set 2 | vila do maio
# Processing Record 33 of Set 2 | san patricio
# Processing Record 34 of Set 2 | boyolangu
# Processing Record 35 of Set 2 | doka
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | berlevag
# Processing Record 38 of Set 2 | boa vista
# Processing Record 39 of Set 2 | trincomalee
# Processing Record 40 of Set 2 | qaqortoq
# Processing Record 41 of Set 2 | rio grande
# Processing Record 42 of Set 2 | senador pompeu
# Processing Record 43 of Set 2 | souillac
# Processing Record 44 of Set 2 | cherskiy
# Processing Record 45 of Set 2 | anadyr
# Processing Record 46 of Set 2 | sao filipe
# Processing Record 47 of Set 2 | masaka
# Processing Record 48 of Set 2 | hithadhoo
# Processing Record 49 of Set 2 | kaduna
# Processing Record 50 of Set 2 | ust-ilimsk
# Processing Record 1 of Set 3 | rutana
# Processing Record 2 of Set 3 | antofagasta
# Processing Record 3 of Set 3 | pelotas
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | sombrio
# Processing Record 6 of Set 3 | beringovskiy
# Processing Record 7 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 3 | joniskis
# Processing Record 9 of Set 3 | hovd
# Processing Record 10 of Set 3 | grootfontein
# Processing Record 11 of Set 3 | khao yoi
# Processing Record 12 of Set 3 | clearlake
# Processing Record 13 of Set 3 | college
# Processing Record 14 of Set 3 | zhangye
# Processing Record 15 of Set 3 | luderitz
# Processing Record 16 of Set 3 | sawakin
# Processing Record 17 of Set 3 | ribeira grande
# Processing Record 18 of Set 3 | olinda
# Processing Record 19 of Set 3 | zhezkazgan
# Processing Record 20 of Set 3 | mount gambier
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | sao joao da barra
# Processing Record 23 of Set 3 | rafaela
# Processing Record 24 of Set 3 | tasiilaq
# Processing Record 25 of Set 3 | vao
# Processing Record 26 of Set 3 | sola
# Processing Record 27 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 3 | ust-donetskiy
# Processing Record 29 of Set 3 | margherita
# Processing Record 30 of Set 3 | damghan
# Processing Record 31 of Set 3 | killybegs
# Processing Record 32 of Set 3 | lagoa
# Processing Record 33 of Set 3 | clyde river
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | iqaluit
# Processing Record 36 of Set 3 | azimur
# City not found. Skipping...
# Processing Record 37 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 38 of Set 3 | broome
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 3 | mamallapuram
# Processing Record 42 of Set 3 | buarcos
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | bengkulu
# Processing Record 45 of Set 3 | murmashi
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | mutsu
# Processing Record 48 of Set 3 | sorong
# Processing Record 49 of Set 3 | kaoma
# Processing Record 50 of Set 3 | mayo
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | yellowknife
# Processing Record 3 of Set 4 | saskylakh
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | bhakkar
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | isiro
# Processing Record 8 of Set 4 | noyabrsk
# Processing Record 9 of Set 4 | rocha
# Processing Record 10 of Set 4 | madang
# Processing Record 11 of Set 4 | san juan
# Processing Record 12 of Set 4 | kodiak
# Processing Record 13 of Set 4 | yilan
# Processing Record 14 of Set 4 | manicore
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | leningradskiy
# Processing Record 18 of Set 4 | marawi
# Processing Record 19 of Set 4 | vila franca do campo
# Processing Record 20 of Set 4 | plouzane
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | lompoc
# Processing Record 24 of Set 4 | arlit
# Processing Record 25 of Set 4 | tungor
# Processing Record 26 of Set 4 | solnechnyy
# Processing Record 27 of Set 4 | moron
# Processing Record 28 of Set 4 | pevek
# Processing Record 29 of Set 4 | kirovsk
# Processing Record 30 of Set 4 | tebingtinggi
# Processing Record 31 of Set 4 | andenes
# Processing Record 32 of Set 4 | santa maria
# Processing Record 33 of Set 4 | guerrero negro
# Processing Record 34 of Set 4 | dingle
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | laguna
# Processing Record 37 of Set 4 | waingapu
# Processing Record 38 of Set 4 | yulara
# Processing Record 39 of Set 4 | alofi
# Processing Record 40 of Set 4 | pitimbu
# Processing Record 41 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 4 | high level
# Processing Record 43 of Set 4 | wichita falls
# Processing Record 44 of Set 4 | victoria
# Processing Record 45 of Set 4 | adrar
# Processing Record 46 of Set 4 | faya
# Processing Record 47 of Set 4 | port alfred
# Processing Record 48 of Set 4 | kismayo
# Processing Record 49 of Set 4 | awjilah
# Processing Record 50 of Set 4 | cairns
# Processing Record 1 of Set 5 | nedjo
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | esmeraldas
# Processing Record 4 of Set 5 | smithers
# Processing Record 5 of Set 5 | chuy
# Processing Record 6 of Set 5 | bergen
# Processing Record 7 of Set 5 | kailua
# Processing Record 8 of Set 5 | kankakee
# Processing Record 9 of Set 5 | baruun-urt
# Processing Record 10 of Set 5 | salalah
# Processing Record 11 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | kahului
# Processing Record 14 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 15 of Set 5 | mabaruma
# Processing Record 16 of Set 5 | inhambane
# Processing Record 17 of Set 5 | katobu
# Processing Record 18 of Set 5 | great yarmouth
# Processing Record 19 of Set 5 | nikolskoye
# Processing Record 20 of Set 5 | port-gentil
# Processing Record 21 of Set 5 | gasa
# Processing Record 22 of Set 5 | jega
# Processing Record 23 of Set 5 | galveston
# Processing Record 24 of Set 5 | zhanakorgan
# Processing Record 25 of Set 5 | poum
# Processing Record 26 of Set 5 | lebedyn
# Processing Record 27 of Set 5 | esna
# Processing Record 28 of Set 5 | teberda
# Processing Record 29 of Set 5 | ouesso
# Processing Record 30 of Set 5 | saldanha
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | lata
# Processing Record 33 of Set 5 | hilo
# Processing Record 34 of Set 5 | riyadh
# Processing Record 35 of Set 5 | magrath
# Processing Record 36 of Set 5 | tabou
# Processing Record 37 of Set 5 | port hardy
# Processing Record 38 of Set 5 | muros
# Processing Record 39 of Set 5 | trabzon
# Processing Record 40 of Set 5 | valparaiso
# Processing Record 41 of Set 5 | tirano
# Processing Record 42 of Set 5 | jenbach
# Processing Record 43 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 5 | qaanaaq
# Processing Record 45 of Set 5 | sechura
# Processing Record 46 of Set 5 | jadu
# Processing Record 47 of Set 5 | ostrovnoy
# Processing Record 48 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 5 | chumikan
# Processing Record 50 of Set 5 | grindavik
# Processing Record 1 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 2 of Set 6 | venado tuerto
# Processing Record 3 of Set 6 | vila velha
# Processing Record 4 of Set 6 | skali
# City not found. Skipping...
# Processing Record 5 of Set 6 | djambala
# Processing Record 6 of Set 6 | ulladulla
# Processing Record 7 of Set 6 | arkadak
# Processing Record 8 of Set 6 | bluff
# Processing Record 9 of Set 6 | iquitos
# Processing Record 10 of Set 6 | jalalabad
# Processing Record 11 of Set 6 | lasa
# Processing Record 12 of Set 6 | velasco ibarra
# Processing Record 13 of Set 6 | lamu
# Processing Record 14 of Set 6 | navahrudak
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | hobyo
# Processing Record 17 of Set 6 | kenai
# Processing Record 18 of Set 6 | san francisco del mar
# Processing Record 19 of Set 6 | chinsali
# Processing Record 20 of Set 6 | meulaboh
# Processing Record 21 of Set 6 | ilulissat
# Processing Record 22 of Set 6 | dunedin
# Processing Record 23 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 24 of Set 6 | sumbe
# Processing Record 25 of Set 6 | alta floresta
# Processing Record 26 of Set 6 | yuli
# Processing Record 27 of Set 6 | soke
# Processing Record 28 of Set 6 | maun
# Processing Record 29 of Set 6 | sibolga
# Processing Record 30 of Set 6 | paranapanema
# Processing Record 31 of Set 6 | henties bay
# Processing Record 32 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 6 | sosnovo-ozerskoye
# Processing Record 34 of Set 6 | sabang
# Processing Record 35 of Set 6 | the valley
# Processing Record 36 of Set 6 | norman wells
# Processing Record 37 of Set 6 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 6 | bajil
# Processing Record 39 of Set 6 | honiara
# Processing Record 40 of Set 6 | tazmalt
# Processing Record 41 of Set 6 | norsup
# Processing Record 42 of Set 6 | katsuura
# Processing Record 43 of Set 6 | provideniya
# Processing Record 44 of Set 6 | boende
# Processing Record 45 of Set 6 | lagoa vermelha
# Processing Record 46 of Set 6 | dhidhdhoo
# Processing Record 47 of Set 6 | auki
# Processing Record 48 of Set 6 | kloulklubed
# Processing Record 49 of Set 6 | westport
# Processing Record 50 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 7 | cody
# Processing Record 2 of Set 7 | aykhal
# Processing Record 3 of Set 7 | zyryanka
# Processing Record 4 of Set 7 | oranjemund
# Processing Record 5 of Set 7 | asfi
# Processing Record 6 of Set 7 | nauta
# Processing Record 7 of Set 7 | tura
# Processing Record 8 of Set 7 | menongue
# Processing Record 9 of Set 7 | big spring
# Processing Record 10 of Set 7 | hokitika
# Processing Record 11 of Set 7 | teguise
# Processing Record 12 of Set 7 | huarmey
# Processing Record 13 of Set 7 | misratah
# Processing Record 14 of Set 7 | cabo san lucas
# Processing Record 15 of Set 7 | mana
# Processing Record 16 of Set 7 | ozernovskiy
# Processing Record 17 of Set 7 | inuvik
# Processing Record 18 of Set 7 | dibaya
# City not found. Skipping...
# Processing Record 19 of Set 7 | oltu
# Processing Record 20 of Set 7 | magole
# Processing Record 21 of Set 7 | gat
# Processing Record 22 of Set 7 | anchorage
# Processing Record 23 of Set 7 | codrington
# Processing Record 24 of Set 7 | gold coast
# Processing Record 25 of Set 7 | broska
# Processing Record 26 of Set 7 | pleshanovo
# Processing Record 27 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 7 | balkhash
# Processing Record 29 of Set 7 | minot
# Processing Record 30 of Set 7 | touros
# Processing Record 31 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 7 | tucupita
# Processing Record 34 of Set 7 | daryapur
# Processing Record 35 of Set 7 | beipiao
# Processing Record 36 of Set 7 | bemidji
# Processing Record 37 of Set 7 | stornoway
# Processing Record 38 of Set 7 | jalu
# Processing Record 39 of Set 7 | northam
# Processing Record 40 of Set 7 | beverungen
# Processing Record 41 of Set 7 | coquimbo
# Processing Record 42 of Set 7 | minggang
# Processing Record 43 of Set 7 | mbuji-mayi
# Processing Record 44 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 45 of Set 7 | soe
# Processing Record 46 of Set 7 | atambua
# Processing Record 47 of Set 7 | diego de almagro
# Processing Record 48 of Set 7 | saleilua
# City not found. Skipping...
# Processing Record 49 of Set 7 | muli
# Processing Record 50 of Set 7 | tessalit
# Processing Record 1 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 8 | kamaishi
# Processing Record 3 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 4 of Set 8 | saint george
# Processing Record 5 of Set 8 | torrington
# Processing Record 6 of Set 8 | thinadhoo
# Processing Record 7 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 8 of Set 8 | palana
# Processing Record 9 of Set 8 | cockburn town
# Processing Record 10 of Set 8 | ilhabela
# Processing Record 11 of Set 8 | port blair
# Processing Record 12 of Set 8 | luanda
# Processing Record 13 of Set 8 | coihaique
# Processing Record 14 of Set 8 | tautira
# Processing Record 15 of Set 8 | santarem
# Processing Record 16 of Set 8 | tierralta
# Processing Record 17 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 8 | sergeyevka
# Processing Record 19 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 8 | campechuela
# Processing Record 21 of Set 8 | gornopravdinsk
# Processing Record 22 of Set 8 | oussouye
# Processing Record 23 of Set 8 | asau
# Processing Record 24 of Set 8 | ballangen
# Processing Record 25 of Set 8 | lockhart
# Processing Record 26 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 8 | tocopilla
# Processing Record 28 of Set 8 | haines junction
# Processing Record 29 of Set 8 | denpasar
# Processing Record 30 of Set 8 | la ronge
# Processing Record 31 of Set 8 | valdivia
# Processing Record 32 of Set 8 | nanchang
# Processing Record 33 of Set 8 | waipawa
# Processing Record 34 of Set 8 | burica
# City not found. Skipping...
# Processing Record 35 of Set 8 | doha
# Processing Record 36 of Set 8 | kajansi
# Processing Record 37 of Set 8 | flin flon
# Processing Record 38 of Set 8 | margate
# Processing Record 39 of Set 8 | hienghene
# Processing Record 40 of Set 8 | beloha
# Processing Record 41 of Set 8 | oriximina
# Processing Record 42 of Set 8 | riviere-au-renard
# Processing Record 43 of Set 8 | srednekolymsk
# Processing Record 44 of Set 8 | neuquen
# Processing Record 45 of Set 8 | poya
# Processing Record 46 of Set 8 | loralai
# Processing Record 47 of Set 8 | nova olinda do norte
# Processing Record 48 of Set 8 | urucara
# Processing Record 49 of Set 8 | hasaki
# Processing Record 50 of Set 8 | pocri
# Processing Record 1 of Set 9 | kamenka
# Processing Record 2 of Set 9 | te anau
# Processing Record 3 of Set 9 | aksu
# Processing Record 4 of Set 9 | porto novo
# Processing Record 5 of Set 9 | camana
# Processing Record 6 of Set 9 | gigmoto
# Processing Record 7 of Set 9 | harindanga
# Processing Record 8 of Set 9 | port lincoln
# Processing Record 9 of Set 9 | rassvet
# Processing Record 10 of Set 9 | trelew
# Processing Record 11 of Set 9 | eydhafushi
# Processing Record 12 of Set 9 | marystown
# Processing Record 13 of Set 9 | buenavista
# Processing Record 14 of Set 9 | pavilosta
# Processing Record 15 of Set 9 | tulagi
# Processing Record 16 of Set 9 | port macquarie
# Processing Record 17 of Set 9 | mahebourg
# Processing Record 18 of Set 9 | preobrazheniye
# Processing Record 19 of Set 9 | kontagora
# Processing Record 20 of Set 9 | dawson creek
# Processing Record 21 of Set 9 | howard springs
# Processing Record 22 of Set 9 | paamiut
# Processing Record 23 of Set 9 | kayunga
# Processing Record 24 of Set 9 | iwanai
# Processing Record 25 of Set 9 | bosaso
# Processing Record 26 of Set 9 | damaturu
# Processing Record 27 of Set 9 | evensk
# Processing Record 28 of Set 9 | elko
# Processing Record 29 of Set 9 | russkiy
# Processing Record 30 of Set 9 | lethem
# Processing Record 31 of Set 9 | kargasok
# Processing Record 32 of Set 9 | nowy dwor gdanski
# Processing Record 33 of Set 9 | balabac
# Processing Record 34 of Set 9 | sharan
# Processing Record 35 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 36 of Set 9 | san quintin
# Processing Record 37 of Set 9 | sisimiut
# Processing Record 38 of Set 9 | jurado
# Processing Record 39 of Set 9 | christchurch
# Processing Record 40 of Set 9 | riedlingen
# Processing Record 41 of Set 9 | witrivier
# City not found. Skipping...
# Processing Record 42 of Set 9 | zacualpan
# Processing Record 43 of Set 9 | aktau
# Processing Record 44 of Set 9 | coruripe
# Processing Record 45 of Set 9 | picayune
# Processing Record 46 of Set 9 | mega
# Processing Record 47 of Set 9 | randazzo
# Processing Record 48 of Set 9 | roald
# Processing Record 49 of Set 9 | marsa matruh
# Processing Record 50 of Set 9 | mirabad
# Processing Record 1 of Set 10 | comacchio
# Processing Record 2 of Set 10 | mizan teferi
# Processing Record 3 of Set 10 | bitung
# Processing Record 4 of Set 10 | madimba
# Processing Record 5 of Set 10 | kishi
# Processing Record 6 of Set 10 | shieli
# Processing Record 7 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 8 of Set 10 | mbanza-ngungu
# Processing Record 9 of Set 10 | azangaro
# Processing Record 10 of Set 10 | ambon
# Processing Record 11 of Set 10 | tuatapere
# Processing Record 12 of Set 10 | anaconda
# Processing Record 13 of Set 10 | airai
# Processing Record 14 of Set 10 | saint peters
# Processing Record 15 of Set 10 | geraldton
# Processing Record 16 of Set 10 | novyye lyady
# Processing Record 17 of Set 10 | pomabamba
# Processing Record 18 of Set 10 | nioro
# Processing Record 19 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 10 | hami
# Processing Record 21 of Set 10 | pittsburg
# Processing Record 22 of Set 10 | tynda
# Processing Record 23 of Set 10 | kavaratti
# Processing Record 24 of Set 10 | pontianak
# Processing Record 25 of Set 10 | los llanos de aridane
# Processing Record 26 of Set 10 | vangaindrano
# Processing Record 27 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | kang
# Processing Record 29 of Set 10 | stancuta
# Processing Record 30 of Set 10 | campos
# Processing Record 31 of Set 10 | aswan
# Processing Record 32 of Set 10 | thilogne
# City not found. Skipping...
# Processing Record 33 of Set 10 | sobolevo
# Processing Record 34 of Set 10 | tuntum
# Processing Record 35 of Set 10 | kutum
# Processing Record 36 of Set 10 | portland
# Processing Record 37 of Set 10 | erken-shakhar
# City not found. Skipping...
# Processing Record 38 of Set 10 | nalchiti
# Processing Record 39 of Set 10 | dhuburi
# Processing Record 40 of Set 10 | mount isa
# Processing Record 41 of Set 10 | gwadar
# Processing Record 42 of Set 10 | smidovich
# Processing Record 43 of Set 10 | narsaq
# Processing Record 44 of Set 10 | imbituba
# Processing Record 45 of Set 10 | miaoli
# Processing Record 46 of Set 10 | acatzingo
# Processing Record 47 of Set 10 | namatanai
# Processing Record 48 of Set 10 | kyaikto
# Processing Record 49 of Set 10 | kaeo
# Processing Record 50 of Set 10 | espinal
# Processing Record 1 of Set 11 | flinders
# Processing Record 2 of Set 11 | camalu
# Processing Record 3 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 11 | acapulco
# Processing Record 5 of Set 11 | amuntai
# Processing Record 6 of Set 11 | pastavy
# Processing Record 7 of Set 11 | karratha
# Processing Record 8 of Set 11 | longonjo
# Processing Record 9 of Set 11 | punta alta
# Processing Record 10 of Set 11 | vaitape
# Processing Record 11 of Set 11 | makakilo city
# Processing Record 12 of Set 11 | milkovo
# Processing Record 13 of Set 11 | bullhead city
# Processing Record 14 of Set 11 | nishihara
# Processing Record 15 of Set 11 | ursulo galvan
# Processing Record 16 of Set 11 | batagay-alyta
# Processing Record 17 of Set 11 | khani
# Processing Record 18 of Set 11 | trofors
# Processing Record 19 of Set 11 | imeni poliny osipenko
# Processing Record 20 of Set 11 | klaksvik
# Processing Record 21 of Set 11 | indramayu
# Processing Record 22 of Set 11 | mozhaysk
# Processing Record 23 of Set 11 | tecoanapa
# Processing Record 24 of Set 11 | dakoro
# Processing Record 25 of Set 11 | brae
# Processing Record 26 of Set 11 | barranca
# Processing Record 27 of Set 11 | jining
# Processing Record 28 of Set 11 | sabirabad
# Processing Record 29 of Set 11 | cap malheureux
# Processing Record 30 of Set 11 | avera
# Processing Record 31 of Set 11 | teahupoo
# Processing Record 32 of Set 11 | lhokseumawe
# Processing Record 33 of Set 11 | dumbea
# Processing Record 34 of Set 11 | puerto escondido
# Processing Record 35 of Set 11 | clarence town
# Processing Record 36 of Set 11 | calvinia
# Processing Record 37 of Set 11 | cuenca
# Processing Record 38 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 39 of Set 11 | selenduma
# Processing Record 40 of Set 11 | dingli
# Processing Record 41 of Set 11 | kulhudhuffushi
# Processing Record 42 of Set 11 | grand gaube
# Processing Record 43 of Set 11 | werda
# Processing Record 44 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 45 of Set 11 | egvekinot
# Processing Record 46 of Set 11 | japura
# Processing Record 47 of Set 11 | karwar
# Processing Record 48 of Set 11 | charters towers
# Processing Record 49 of Set 11 | akyab
# Processing Record 50 of Set 11 | broken hill
# Processing Record 1 of Set 12 | camacupa
# Processing Record 2 of Set 12 | williams lake
# Processing Record 3 of Set 12 | princeton
# Processing Record 4 of Set 12 | kirakira
# Processing Record 5 of Set 12 | alexandria
# Processing Record 6 of Set 12 | bani walid
# Processing Record 7 of Set 12 | camacha
# Processing Record 8 of Set 12 | san blas
# Processing Record 9 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 12 | necochea
# Processing Record 11 of Set 12 | atasu
# Processing Record 12 of Set 12 | salinopolis
# Processing Record 13 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 14 of Set 12 | belmonte
# Processing Record 15 of Set 12 | pangnirtung
# Processing Record 16 of Set 12 | urumqi
# Processing Record 17 of Set 12 | bossier city
# Processing Record 18 of Set 12 | baoro
# Processing Record 19 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 12 | vitim
# Processing Record 21 of Set 12 | paka
# Processing Record 22 of Set 12 | bentiu
# Processing Record 23 of Set 12 | pimentel
# Processing Record 24 of Set 12 | dhulian
# Processing Record 25 of Set 12 | shubarkuduk
# Processing Record 26 of Set 12 | polunochnoye
# Processing Record 27 of Set 12 | mahibadhoo
# Processing Record 28 of Set 12 | dongsheng
# Processing Record 29 of Set 12 | moundou
# Processing Record 30 of Set 12 | promyshlennyy
# Processing Record 31 of Set 12 | barpali
# Processing Record 32 of Set 12 | anna paulowna
# Processing Record 33 of Set 12 | presidencia roque saenz pena
# Processing Record 34 of Set 12 | matagami
# Processing Record 35 of Set 12 | alta gracia
# Processing Record 36 of Set 12 | mahon
# Processing Record 37 of Set 12 | chernyshevskiy
# Processing Record 38 of Set 12 | yerbogachen
# Processing Record 39 of Set 12 | gizo
# Processing Record 40 of Set 12 | malaya vishera
# Processing Record 41 of Set 12 | banjar
# Processing Record 42 of Set 12 | cayenne
# Processing Record 43 of Set 12 | casino
# Processing Record 44 of Set 12 | bac lieu
# Processing Record 45 of Set 12 | san marcos
# Processing Record 46 of Set 12 | bogorodskoye
# Processing Record 47 of Set 12 | tiznit
# Processing Record 48 of Set 12 | kajaani
# Processing Record 49 of Set 12 | gucheng
# Processing Record 50 of Set 12 | udachnyy
# Processing Record 1 of Set 13 | san andres
# Processing Record 2 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 13 | krasnoarmeysk
# Processing Record 4 of Set 13 | itoman
# Processing Record 5 of Set 13 | itupiranga
# Processing Record 6 of Set 13 | pochinki
# Processing Record 7 of Set 13 | fukue
# Processing Record 8 of Set 13 | agirish
# Processing Record 9 of Set 13 | syracuse
# Processing Record 10 of Set 13 | nouadhibou
# Processing Record 11 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 12 of Set 13 | senneterre
# Processing Record 13 of Set 13 | arman
# Processing Record 14 of Set 13 | muisne
# Processing Record 15 of Set 13 | gubkinskiy
# Processing Record 16 of Set 13 | zhigansk
# Processing Record 17 of Set 13 | ilyich
# Processing Record 18 of Set 13 | lepe
# Processing Record 19 of Set 13 | douglas
# Processing Record 20 of Set 13 | palora
# Processing Record 21 of Set 13 | naze
# Processing Record 22 of Set 13 | magadan
# Processing Record 23 of Set 13 | waddan
# Processing Record 24 of Set 13 | mirnyy
# Processing Record 25 of Set 13 | talcahuano
# Processing Record 26 of Set 13 | rehoboth
# Processing Record 27 of Set 13 | baryatino
# Processing Record 28 of Set 13 | boca do acre
# Processing Record 29 of Set 13 | vardo
# Processing Record 30 of Set 13 | vilhena
# Processing Record 31 of Set 13 | novyy nekouz
# Processing Record 32 of Set 13 | baiao
# Processing Record 33 of Set 13 | hamilton
# Processing Record 34 of Set 13 | key biscayne
# Processing Record 35 of Set 13 | nykoping
# Processing Record 36 of Set 13 | bahadurganj
# Processing Record 37 of Set 13 | bellevue
# Processing Record 38 of Set 13 | sumter
# Processing Record 39 of Set 13 | joaima
# Processing Record 40 of Set 13 | caldas novas
# Processing Record 41 of Set 13 | rockford
# Processing Record 42 of Set 13 | high prairie
# Processing Record 43 of Set 13 | bathsheba
# Processing Record 44 of Set 13 | ichhawar
# Processing Record 45 of Set 13 | mamlyutka
# Processing Record 46 of Set 13 | te karaka
# Processing Record 47 of Set 13 | plettenberg bay
# Processing Record 48 of Set 13 | vostok
# Processing Record 49 of Set 13 | pacific grove
# Processing Record 50 of Set 13 | alakurtti
# Processing Record 1 of Set 14 | fort nelson
# Processing Record 2 of Set 14 | umm lajj
# Processing Record 3 of Set 14 | aklavik
# Processing Record 4 of Set 14 | sapele
# Processing Record 5 of Set 14 | vagamo
# Processing Record 6 of Set 14 | shadegan
# Processing Record 7 of Set 14 | knysna
# Processing Record 8 of Set 14 | sungaipenuh
# Processing Record 9 of Set 14 | bulawayo
# Processing Record 10 of Set 14 | carutapera
# Processing Record 11 of Set 14 | phalaborwa
# Processing Record 12 of Set 14 | upata
# Processing Record 13 of Set 14 | safakulevo
# Processing Record 14 of Set 14 | khilok
# Processing Record 15 of Set 14 | safaga
# Processing Record 16 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 14 | phan thiet
# Processing Record 18 of Set 14 | lingao
# Processing Record 19 of Set 14 | espanola
# Processing Record 20 of Set 14 | matara
# Processing Record 21 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 22 of Set 14 | koumac
# Processing Record 23 of Set 14 | sept-iles
# Processing Record 24 of Set 14 | porto velho
# Processing Record 25 of Set 14 | seoul
# Processing Record 26 of Set 14 | melito di porto salvo
# Processing Record 27 of Set 14 | yuzha
# Processing Record 28 of Set 14 | berdigestyakh
# Processing Record 29 of Set 14 | olden
# Processing Record 30 of Set 14 | idenao
# Processing Record 31 of Set 14 | yeppoon
# Processing Record 32 of Set 14 | jumla
# Processing Record 33 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 34 of Set 14 | auburn
# Processing Record 35 of Set 14 | inirida
# Processing Record 36 of Set 14 | idritsa
# Processing Record 37 of Set 14 | mumford
# Processing Record 38 of Set 14 | houma
# Processing Record 39 of Set 14 | aguimes
# Processing Record 40 of Set 14 | springdale
# Processing Record 41 of Set 14 | iquique
# Processing Record 42 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 14 | kilakarai
# Processing Record 44 of Set 14 | ingham
# Processing Record 45 of Set 14 | ambilobe
# Processing Record 46 of Set 14 | dom pedrito
# Processing Record 47 of Set 14 | bodinayakkanur
# Processing Record 48 of Set 14 | majene
# Processing Record 49 of Set 14 | tomatlan
# Processing Record 50 of Set 14 | deputatskiy
# Processing Record 1 of Set 15 | ngaoundere
# Processing Record 2 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 15 | tatawin
# Processing Record 4 of Set 15 | litovko
# Processing Record 5 of Set 15 | nizwa
# Processing Record 6 of Set 15 | tual
# Processing Record 7 of Set 15 | ambulu
# Processing Record 8 of Set 15 | maragogi
# Processing Record 9 of Set 15 | parrita
# Processing Record 10 of Set 15 | korla
# Processing Record 11 of Set 15 | sawtell
# Processing Record 12 of Set 15 | waitati
# Processing Record 13 of Set 15 | sayyan
# Processing Record 14 of Set 15 | pinan
# Processing Record 15 of Set 15 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 18 of Set 15 | rosario oeste
# Processing Record 19 of Set 15 | mersing
# Processing Record 20 of Set 15 | pine bluff
# Processing Record 21 of Set 15 | nome
# Processing Record 22 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 15 | yar-sale
# Processing Record 24 of Set 15 | say
# Processing Record 25 of Set 15 | khryashchevka
# Processing Record 26 of Set 15 | carauari
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
len(city_data)
# Out:
# 662

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Thompson      CA  55.7435  -97.8558     71.76        60          40
# 1    Ushuaia      AR -54.8000  -68.3000     33.42        93         100
# 2  Jamestown      US  42.0970  -79.2353     88.02        51          40
# 3     Barrow      US  71.2906 -156.7887     51.82        62           0
# 4      Snasa      NO  64.2457   12.3778     60.21        87         100
# 5    Mataura      NZ -46.1927  168.8643     39.47        92         100
# 6      Goure      NE  13.9835   10.2704     77.02        58         100
# 7  Cape Town      ZA -33.9258   18.4232     53.11        63           0
# 8      Buala      SB  -8.1450  159.5921     79.86        80         100
# 9  Busselton      AU -33.6500  115.3333     55.51        95         100
#
#    Wind Speed Current Description
# 0       12.66    scattered clouds
# 1       18.41                snow
# 2       17.27    scattered clouds
# 3        4.61           clear sky
# 4        2.64     overcast clouds
# 5        1.95     overcast clouds
# 6        6.49     overcast clouds
# 7        6.91           clear sky
# 8        6.58     overcast clouds
# 9       15.79          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
